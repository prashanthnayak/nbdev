# %%
#| hide
from myblog.core import *

# %% [markdown]
# # nbdev
#
# > this is an random experiment

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbdev in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/prashanth/nbdev.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c prashanth nbdev
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev
# ```
#
#
# [repo]: https://github.com/prashanth/nbdev
# [docs]: https://prashanth.github.io/nbdev/
# [pypi]: https://pypi.org/project/nbdev/
# [conda]: https://anaconda.org/prashanth/nbdev

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/prashanth/nbdev
# [docs]: https://prashanth.github.io/nbdev/
# [pypi]: https://pypi.org/project/nbdev/
# [conda]: https://anaconda.org/prashanth/nbdev

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
